# %%
# %pylab inline 
# %matplotlib inline 
import pandas as pd
import seaborn as sb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Machine Learning analysis

# %%
high = pd.read_csv('data/hi_pert.csv')
low  = pd.read_csv('data/lo_pert.csv')
nop  = pd.read_csv('data/no_pert.csv')

# %%
high.describe()
# Out:
#          Unnamed: 0         ident             it           t          a(i)  \
# count  15768.000000  15768.000000   15768.000000     15768.0  15768.000000
# mean   10378.988965    870.841958  197783.644089  20000001.0      8.362289
# std     6297.839728    530.104568    5229.050249         0.0      6.224713
# min       11.000000      1.000000  110353.000000  20000001.0      0.034440
# 25%     4994.750000    415.000000  197855.000000  20000001.0      3.173611
# 50%    10029.500000    837.000000  199387.000000  20000001.0      7.392684
# 75%    15351.250000   1288.000000  199885.000000  20000001.0     12.205238
# max    24306.000000   2048.000000  199997.000000  20000001.0     39.079128
#
#           emegas(i)  emepla(i)/emet  rplanet(i)/radtie       emestar  \
# count  15768.000000    15768.000000       15768.000000  1.576800e+04
# mean     143.227183      137.581561           1.221847  2.043560e+33
# std     1212.189969     1182.759817           0.667981  4.088779e+32
# ...

# %%
low.describe()
# Out:
#          Unnamed: 0         ident             it           t          a(i)  \
# count  16076.000000  16076.000000   16076.000000     16076.0  16076.000000
# mean   10645.786701    866.775006  197344.118002  20000001.0      8.215550
# std     6456.936042    531.293856    6000.919019         0.0      6.094459
# min        9.000000      1.000000   46260.000000  20000001.0      0.034357
# 25%     5152.750000    411.000000  197341.000000  20000001.0      3.123693
# 50%    10266.500000    826.000000  199229.000000  20000001.0      7.208504
# 75%    15720.250000   1283.000000  199855.000000  20000001.0     11.998899
# max    24932.000000   2048.000000  199997.000000  20000001.0     39.095903
#
#           emegas(i)  emepla(i)/emet  rplanet(i)/radtie       emestar  \
# count  16076.000000    16076.000000       16076.000000  1.607600e+04
# mean     137.798748      129.998766           1.234880  2.043228e+33
# std     1175.664386     1127.557478           0.666249  4.075326e+32
# ...

# %%
nop.describe()
# Out:
#          Unnamed: 0         ident             it           t          a(i)  \
# count  16194.000000  16194.000000   16194.000000     16194.0  16194.000000
# mean   10330.295295    871.193775  197263.376930  20000001.0      8.071598
# std     5997.510910    532.775824    6126.434158         0.0      6.078375
# min       11.000000      1.000000   72379.000000  20000001.0      0.034439
# 25%     5182.250000    412.000000  197328.000000  20000001.0      2.972736
# 50%    10173.500000    831.000000  199195.500000  20000001.0      7.038554
# 75%    15494.750000   1288.000000  199818.000000  20000001.0     11.840045
# max    20843.000000   2048.000000  199997.000000  20000001.0     37.460658
#
#           emegas(i)  emepla(i)/emet  rplanet(i)/radtie       emestar  \
# count  16194.000000    16194.000000       16194.000000  1.619400e+04
# mean     124.212443      120.887032           1.239330  2.043049e+33
# std     1160.165530     1145.605524           0.658177  4.092630e+32
# ...

# %%
high.columns
# Out:
# Index([u'Unnamed: 0', u'ident', u'it', u't', u'a(i)', u'emegas(i)',
#        u'emepla(i)/emet', u'rplanet(i)/radtie', u'emestar', u'rc', u'qest',
#        u'sigmag_0', u'emed', u'gama', u'apert', u'fpert', u'constmigI',
#        u'emetal', u'taugas'],
#       dtype='object')

# %% [markdown]
# From the descriptive statistics, we can see some insigths:
#
# - The time of simulation ($t$) is equal across samples, then we can neglected.
# - There are the same systems in each sample.
